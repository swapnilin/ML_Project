# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# Lets push this data to out mongoDB cluster
import pymongo

# %% [markdown]
# *MongoDB Structure*
# - **Organization**
#
#   - **Project** (Project0)
#
#     - **Cluster** (the MongoDB server - cluster0128)
#
#       - **Database A** (vehicle)
#
#         - Collections (mlops)
#       - **Database B**
#
#         - Collections
#       - **Database C**

# %%
"""This helps URL-encode the username and password in the connection string. 
Sometimes passwords with special characters can cause issues if used directly in the connection string
"""
from urllib.parse import quote_plus
username = quote_plus("swapnilforcat")
password = quote_plus("pKpN5uVeMvGI5Evx")

"""MongoDB does not require databases to exist upfront.
A database is created only when data is first written.
"""
DB_NAME = "vehicle"
COLLECTION_NAME = "mlops"
CONNECTION_URL = f"mongodb+srv://{username}:{password}@cluster0128.u5ambai.mongodb.net/?appName=cluster0128"

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Upload data to MongoDB
rec = collection.insert_many(data)

# %%
DB_NAME = "vehicle"
COLLECTION_NAME = "mlops"
CONNECTION_URL = "mongodb+srv://{username}:{password}@cluster0128.u5ambai.mongodb.net/?appName=cluster0128"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# data in mongoDB can be loaded only as key:value pairs. Convert the dataframe as dict
data = df.to_dict(orient='records')

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Uploading data to MongoDB
# ----> 2 rec = collection.insert_many(data)
#
# File /opt/anaconda3/envs/project/lib/python3.10/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/project/lib/python3.10/site-packages/pymongo/synchronous/collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
# ...
